# %% [markdown]
# # XRoration (XGate) - Keras Tuner

# %% [markdown]
# ## Configuration

# %% [markdown]
# Pulse and fidelity computation are computation intensive (slow).

# %%
PULSE_ENABLED = False
FIDELITY_ENABLED = True
RANDOM_SEARCH_ENABLED = False
BAYESIAN_OPTIMIZATION_ENABLED = True
HYPERBAND_ENABLED = False

# %% [markdown]
# Parameters are stored in a shared script.

# %%
from parameters import *

# %% [markdown]
# Enable seeding for reproducibility of the training.

# %% [raw]
# seed = 0
# np.random.seed(seed)
# tf.random.set_seed(seed)

# %% [markdown]
# ## Library

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras_sequential_ascii import keras2ascii
import os
import numpy as np
import pandas as pd

import sys
sys.path.append('..')

from utils.helpers import *

# Disable some console warnings
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-04-08 15:26:59.028842: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# ## Check GPU

# %% [raw]
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Load

# %%
x_train = np.load('./data/xrotation/{}/x_train.npy'.format(CSV_CONFIG))
x_val = np.load('./data/xrotation/{}/x_val.npy'.format(CSV_CONFIG))
x_test = np.load('./data/xrotation/{}/x_test.npy'.format(CSV_CONFIG))
y_train = np.load('./data/xrotation/{}/y_train.npy'.format(CSV_CONFIG))
y_val = np.load('./data/xrotation/{}/y_val.npy'.format(CSV_CONFIG))
y_test = np.load('./data/xrotation/{}/y_test.npy'.format(CSV_CONFIG))

# %%
N_ANGLES = x_train.shape[1]
N_PARAMS = y_train.shape[1]

# %%
print('---------------------------------------')
print('- Pulse parameters (y) #', N_PARAMS) # ASSUMING 1 BETA VALUE (ANGLE ALONG Y AXIS)
print('- Gate parameters  (x) #', N_ANGLES) # ASSUMING 1 BETA VALUE (ANGLES ALONG Y AXIS)
print('---------------------------------------')
# Out:
# ---------------------------------------
# - Pulse parameters (y) # 20
# - Gate parameters  (x) # 1
# ---------------------------------------

# %% [markdown]
# ### Evaluation

# %% [markdown]
# <span style="color:red">ATTENTION: Measuring fidelity on the entire train, validation, and test sets could be time consuming. Use `limit` parameter in case.</span>

# %% [raw]
# %%time
# if FIDELITY_ENABLED:
#     # Using some hash to avoid name collision
#     import random
#     hash_id = random.getrandbits(32)
#
#     xgate_fidelity_train = get_xgate_fidelity(x_train,
#                                               y_train,
#                                               limit=1000,
#                                               config_template=CONFIG_TEMPLATE_JSON,
#                                               pulse_data_path='/tmp/xgate_{:x}.csv'.format(hash_id),
#                                               output_objf_path='/tmp/xgate_fidelity_{:x}.csv'.format(hash_id))
#     xgate_fidelity_val = get_xgate_fidelity(x_val,
#                                             y_val,
#                                             limit=1000,
#                                             config_template=CONFIG_TEMPLATE_JSON,
#                                             pulse_data_path='/tmp/xgate_{:x}.csv'.format(hash_id),
#                                             output_objf_path='/tmp/xgate_fidelity_{:x}.csv'.format(hash_id))
#     xgate_fidelity_test = get_xgate_fidelity(x_test,
#                                              y_test,
#                                              limit=1000,
#                                              config_template=CONFIG_TEMPLATE_JSON,
#                                              pulse_data_path='/tmp/xgate_{:x}.csv'.format(hash_id),
#                                              output_objf_path='/tmp/xgate_fidelity_{:x}.csv'.format(hash_id))
#
#     print('---------------------------------------')
#     print('Config:', CONFIG_TEMPLATE_JSON)
#     print('Fidelity:')
#     print('- train set:', xgate_fidelity_train)
#     print('- val set:', xgate_fidelity_test)
#     print('- test set:', xgate_fidelity_val)
#     print('---------------------------------------')
# else:
#     xgate_fidelity_train = -1
#     xgate_fidelity_val = -1
#     xgate_fidelity_test = -1
#
#     print('---------------------------------------')
#     print('XGate fidelity: DISABLED')
#     print('---------------------------------------')

# %% [markdown]
# ### Keras Tuner

# %%
from keras_tuner.tuners import RandomSearch, BayesianOptimization, Hyperband

# %%
def sine_activation(x):
    return tf.math.sin(x)

def build_model(hp):
    model = Sequential()
    # Input layer
    model.add(Input(shape=(1,)))
    # N dense +  layers
    for i in range(hp.Int('layers', 1, 7)):
        model.add(
            tf.keras.layers.Dense(
                units = hp.Int('units_' + str(i), 8, 16, step = 4),
                name = 'fc' + str(i)
            )
        )
        #dropout = hp.Boolean("dropout_" + str(i))
        #if dropout:
        #    model.add(keras.layers.Dropout(rate = 0.25))
        #batchnorm = hp.Boolean("batchnorm_" + str(i))
        #if batchnorm:
        #    model.add(keras.layers.BatchNormalization(name = 'batchnorm_' + str(i)))
        model.add(Activation(activation = sine_activation, name = 'sine' + str(i)))
    # Dense layer
    model.add(Dense(units = 20, name = 'fc_last'))
    
    learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-2, sampling="log")

    model.compile(
        optimizer = tf.optimizers.Adam(learning_rate = learning_rate),
        loss = tf.losses.MeanSquaredError(),
        metrics = [   'mean_squared_error'
                      #, tf.metrics.MeanSquaredLogarithmicError()
                      #, tf.metrics.MeanAbsolutePercentageError()
                  ])
    return model

# %%
def slice_data(data, frac):
    return data[:int(data.shape[0]/frac)]

# %% [markdown]
# #### Random Search

# %%
if RANDOM_SEARCH_ENABLED:
    # !rm -rf keras_tuner_random_search
    tuner = RandomSearch(
        build_model,
        objective = 'mean_squared_error',#tf.losses.MeanSquaredError(),
        max_trials = 10,
        executions_per_trial = 5,
        directory = 'keras_tuner_random_search'
    )

# %%
if RANDOM_SEARCH_ENABLED:
    tuner.search_space_summary()

# %%
if RANDOM_SEARCH_ENABLED:
    early_stopping = EarlyStopping(
        monitor='val_loss',
        mode='min',
        patience=30,
        verbose=1)
    tuner.search(slice_data(x_train, 1),
                 slice_data(y_train, 1),
                 epochs = 50,
                 batch_size = 128,
                 callbacks=[early_stopping],
                 validation_data = (slice_data(x_val, 1), slice_data(y_val, 1)),
                 verbose=0)
    tuner.results_summary()

# %%
if RANDOM_SEARCH_ENABLED:
    best_model = tuner.get_best_models()[0]

# %%
if RANDOM_SEARCH_ENABLED:
    best_hps = tuner.get_best_hyperparameters(5)
    #model = build_model(best_hps[0])

# %%
if RANDOM_SEARCH_ENABLED:
    model = best_model
    model.summary()

# %%
if RANDOM_SEARCH_ENABLED:
    keras2ascii(model)

# %%
if RANDOM_SEARCH_ENABLED:
    model_id = 'ktrs_MLP_' + get_basic_id(model)
    print(model_id)

# %% [markdown]
# #### Bayesian Optimization

# %%
if BAYESIAN_OPTIMIZATION_ENABLED:
    # !rm -rf keras_tuner_baesian_optimization
    tuner = BayesianOptimization(
        build_model,
        objective = 'mean_squared_error',
        max_trials = 30,
        executions_per_trial = 5,
        directory = 'keras_tuner_baesian_optimization'   
    )
# Out:
# 2023-04-08 15:27:00.511095: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2023-04-08 15:27:00.517404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1080 computeCapability: 6.1
# coreClock: 1.7335GHz coreCount: 20 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 298.32GiB/s
# 2023-04-08 15:27:00.517427: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2023-04-08 15:27:00.519201: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2023-04-08 15:27:00.519246: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2023-04-08 15:27:00.519875: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2023-04-08 15:27:00.520052: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2023-04-08 15:27:00.520123: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcusolver.so.10'; dlerror: libcusolver.so.10: cannot open shared object file: No such file or directory
# 2023-04-08 15:27:00.520564: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2023-04-08 15:27:00.520665: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2023-04-08 15:27:00.520673: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1757] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-04-08 15:27:00.529856: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 4007945000 Hz
# 2023-04-08 15:27:00.530085: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e211792d00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2023-04-08 15:27:00.530096: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2023-04-08 15:27:00.531654: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-04-08 15:27:00.531663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]

# %%
if BAYESIAN_OPTIMIZATION_ENABLED:
    tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 3
# layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 7, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 16, 'step': 4, 'sampling': 'linear'}
# lr (Float)
# {'default': 0.0001, 'conditions': [], 'min_value': 0.0001, 'max_value': 0.01, 'step': None, 'sampling': 'log'}

# %%
if BAYESIAN_OPTIMIZATION_ENABLED:
    early_stopping = EarlyStopping(
        monitor='val_loss',
        mode='min',
        patience=30,
        verbose=1)
    tuner.search(slice_data(x_train, 1),
             slice_data(y_train, 1),
             epochs = 700,
             batch_size = 128,
             validation_data = (slice_data(x_val, 1), slice_data(y_val, 1)),
             use_multiprocessing=True,
             callbacks=[early_stopping],
             workers=6,
             verbose=0)
    tuner.results_summary()
# Out:
# 2023-04-08 15:27:00.717608: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# Epoch 00038: early stopping
# Epoch 00037: early stopping
# Epoch 00037: early stopping
# Epoch 00036: early stopping
# Epoch 00050: early stopping
# Epoch 00038: early stopping
# Epoch 00050: early stopping
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in keras_tuner_baesian_optimization/untitled_project
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7f9259acec10>
# Trial summary
# Hyperparameters:
# layers: 6
# units_0: 8
# lr: 0.00041670437570096735
# units_1: 8
# units_2: 8
# units_3: 12
# units_4: 16
# units_5: 16
# units_6: 16
# Score: 9.117241688727517e-07
# Trial summary
# Hyperparameters:
# layers: 7
# units_0: 16
# lr: 0.0053405972699974436
# units_1: 16
# units_2: 8
# units_3: 8
# units_4: 8
# units_5: 8
# units_6: 8
# Score: 9.394985795552202e-07
# Trial summary
# Hyperparameters:
# layers: 4
# units_0: 16
# lr: 0.00046155592162824545
# units_1: 8
# units_2: 16
# units_3: 12
# units_4: 16
# units_5: 16
# units_6: 8
# Score: 9.499567681814369e-07
# Trial summary
# Hyperparameters:
# layers: 3
# units_0: 8
# lr: 0.0017779306516158035
# units_1: 8
# units_2: 8
# Score: 9.653829010858318e-07
# Trial summary
# Hyperparameters:
# layers: 3
# units_0: 12
# lr: 0.0075737400739035255
# units_1: 8
# units_2: 8
# units_3: 16
# units_4: 16
# units_5: 12
# units_6: 12
# Score: 1.4045466514289728e-06

# %%
if BAYESIAN_OPTIMIZATION_ENABLED:
    best_model = tuner.get_best_models()[0]

# %%
if BAYESIAN_OPTIMIZATION_ENABLED:
    best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
    #model = build_model(best_hps[0])

# %%
if BAYESIAN_OPTIMIZATION_ENABLED:
    model = best_model
    model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc0 (Dense)                  (None, 8)                 16
# _________________________________________________________________
# sine0 (Activation)           (None, 8)                 0
# _________________________________________________________________
# fc1 (Dense)                  (None, 8)                 72
# _________________________________________________________________
# sine1 (Activation)           (None, 8)                 0
# _________________________________________________________________
# fc2 (Dense)                  (None, 8)                 72
# _________________________________________________________________
# sine2 (Activation)           (None, 8)                 0
# _________________________________________________________________
# fc3 (Dense)                  (None, 12)                108
# _________________________________________________________________
# sine3 (Activation)           (None, 12)                0
# _________________________________________________________________
# fc4 (Dense)                  (None, 16)                208
# _________________________________________________________________
# sine4 (Activation)           (None, 16)                0
# _________________________________________________________________
# fc5 (Dense)                  (None, 16)                272
# _________________________________________________________________
# sine5 (Activation)           (None, 16)                0
# _________________________________________________________________
# fc_last (Dense)              (None, 20)                340
# =================================================================
# Total params: 1,088
# Trainable params: 1,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
if BAYESIAN_OPTIMIZATION_ENABLED:
# Out:
#            OPERATION           DATA DIMENSIONS   WEIGHTS(N)   WEIGHTS(%)
#
#                Input   #####           1
#                Dense   XXXXX -------------------        16     1.5%
#      sine_activation   #####           8
#                Dense   XXXXX -------------------        72     6.6%
#      sine_activation   #####           8
#                Dense   XXXXX -------------------        72     6.6%
#      sine_activation   #####           8
#                Dense   XXXXX -------------------       108     9.9%
#      sine_activation   #####          12
#                Dense   XXXXX -------------------       208    19.1%
#      sine_activation   #####          16
#                Dense   XXXXX -------------------       272    25.0%
#      sine_activation   #####          16
#                Dense   XXXXX -------------------       340    31.2%
#                        #####          20

# %%
if BAYESIAN_OPTIMIZATION_ENABLED:
    model_id = 'ktbo_MLP_' + get_basic_id(model)
    print(model_id)
# Out:
# ktbo_MLP_1x8x8x8x12x16x16x20

# %% [markdown]
# #### Hyperband

# %%
if HYPERBAND_ENABLED:
    # !rm -rf keras_tuner_hyperband
    tuner = Hyperband(
        build_model,
        objective = 'val_loss',
        max_epochs = 50,
        executions_per_trial = 5,
        directory = 'keras_tuner_hyperband'
    )

# %%
if HYPERBAND_ENABLED:
    tuner.search_space_summary()

# %%
if HYPERBAND_ENABLED:
    early_stopping = EarlyStopping(
        monitor='val_loss',
        mode='min',
        patience=30,
        verbose=1)
    tuner.search(slice_data(x_train, 1),
                 slice_data(y_train, 1),
                 epochs = 50,
                 batch_size = 128,
                 validation_data = (slice_data(x_val, 1), slice_data(y_val, 1)),
                 use_multiprocessing=True,
                 callbacks=[early_stopping],
                 workers=6,
                 verbose=0)
    tuner.results_summary()

# %%
if HYPERBAND_ENABLED:
    best_model = tuner.get_best_models()[0]

# %%
if HYPERBAND_ENABLED:
    best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
    #1model = build_model(best_hps[0])

# %%
if HYPERBAND_ENABLED:
    model = best_model
    model.summary()

# %%
if HYPERBAND_ENABLED:
    keras2ascii(model)

# %%
if HYPERBAND_ENABLED:
    model_id = 'kthb_MLP_' + get_basic_id(model)
    print(model_id)

# %% [markdown]
# ### Training

# %%
best_model_file = PREFIX + '/best_keras_model.h5'
last_model_file = PREFIX + '/last_keras_model.h5'

# %% [markdown]
# Enable training (`train_and_save`) to overwrite the model file.

# %%
train_and_save = True

# %%
print(best_hps.get('lr'))
# Out:
# 0.00041670437570096735

# %%
model.compile(optimizer=tf.optimizers.Adam(lr=best_hps.get('lr')),
              loss=tf.losses.MeanSquaredError(),
              metrics=['mean_squared_error'])
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
# %%time
history = None
if train_and_save:
    early_stopping = EarlyStopping(
        monitor='val_loss',
        mode='min',
        patience=30,
        verbose=1)
    model_checkpoint = ModelCheckpoint(
        filepath=best_model_file,
        monitor='val_loss',
        mode='min',
        save_best_only=True)
    history = model.fit(
        x_train,
        y_train,
        epochs=5000,
        batch_size=128, # default 32
        validation_data=(x_val, y_val),
        callbacks=[early_stopping, model_checkpoint],
        verbose=1)
    model.save(last_model_file)

# %% [markdown]
# Load the saved best model and use it from now on.

# %%
model = load_model(best_model_file, custom_objects={'sine_activation': sine_activation})

# %% [markdown]
# ### Evaluation

# %% [markdown]
# Although we may plot and print many metrics, we focus only on **Mean Squared Error (MSE).**

# %% [markdown]
# Measure and print metrics.

# %%
#mse, msle, mape = model.evaluate(x_test, y_test)
mse = model.evaluate(x_test, y_test)[0]
msle, mape = None, None
# Out:
# 16384/16384 [==============================] - 6s 339us/step - loss: 1.1857e-07 - mean_squared_error: 1.1857e-07

# %%
mse = model.evaluate(x_val, y_val)[0]
msle, mape = None, None
# Out:
# 4096/4096 [==============================] - 1s 347us/step - loss: 1.2727e-07 - mean_squared_error: 1.2727e-07

# %%
y_keras = model.predict(x_test)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# fc0 (Dense)                  (None, 8)                 16
# _________________________________________________________________
# sine0 (Activation)           (None, 8)                 0
# _________________________________________________________________
# fc1 (Dense)                  (None, 8)                 72
# _________________________________________________________________
# sine1 (Activation)           (None, 8)                 0
# _________________________________________________________________
# fc2 (Dense)                  (None, 8)                 72
# _________________________________________________________________
# sine2 (Activation)           (None, 8)                 0
# _________________________________________________________________
# fc3 (Dense)                  (None, 12)                108
# _________________________________________________________________
# sine3 (Activation)           (None, 12)                0
# _________________________________________________________________
# fc4 (Dense)                  (None, 16)                208
# _________________________________________________________________
# sine4 (Activation)           (None, 16)                0
# _________________________________________________________________
# fc5 (Dense)                  (None, 16)                272
# _________________________________________________________________
# sine5 (Activation)           (None, 16)                0
# _________________________________________________________________
# fc_last (Dense)              (None, 20)                340
# =================================================================
# Total params: 1,088
# Trainable params: 1,088
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Plot animation of a sorted test set along with its predictions

# %%
import matplotlib.animation as animation
from IPython.display import HTML
import matplotlib.pyplot as plt

# Sort the test values by beta

XY_actual = np.concatenate((x_test, y_test), axis=1)
XY_pred = np.concatenate((x_test, y_keras), axis=1)

#XY_actual = sort_array(XY_actual)
#XY_pred = sort_array(XY_pred)

XY_actual = XY_actual[XY_actual[:,0].argsort()]

XY_pred = XY_pred[XY_pred[:,0].argsort()]

#print(XY_actual)
#print(XY_pred)

## Needs ffmpeg. Install using "conda install -c conda-forge ffmpeg"
start_idx = 1800
num_frames = 500
frame_interval_ms = 100

# get x and y
x = np.arange(1, N_PARAMS+1, 1)
#y = y_test[start_idx:start_idx+num_frames,:]
#y_pred = y_keras[start_idx:start_idx+num_frames,:]
#beta = x_test[start_idx:start_idx+num_frames,:]
y = XY_actual[start_idx:start_idx+num_frames,N_ANGLES:]
beta = XY_actual[start_idx:start_idx+num_frames,:N_ANGLES]
y_pred = XY_pred[start_idx:start_idx+num_frames,N_ANGLES:]

print(y.shape)
print(beta.shape)
print(y_pred.shape)

# create a figure and an axis object
plt.ioff()
fig, ax = plt.subplots()

# set labels and plot limits
plt.ylabel('Pulse parameter values')
plt.xlabel('Pulse parameters (α[1:{}])'.format(N_PARAMS))
#plt.ylim([min_pparam_value, max_pparam_value*5/4])
plt.xticks(x, x)

# initialize an empty line object
line, = ax.plot([], [], marker='o', linestyle='--', color='r', label='actual')
line_pr, = ax.plot([], [], marker='o', linestyle='--', color='g', label='predicted')
ax.legend()

# create a text object inside the axes
title = ax.text(0.05, 0.9, "", transform=ax.transAxes)

# define a function that updates the line object for each frame
def animate(i):
    title.set_text(f"Beta: {beta[i]}")
    # update line data
    line.set_data(x, y[i])
    line_pr.set_data(x, y_pred[i])
    return line,

# create an animation object using FuncAnimation
anim = animation.FuncAnimation(fig, animate,
                              frames=num_frames,
                              interval=frame_interval_ms,
                              repeat=False)

# show the animation
# %matplotlib inline
HTML(anim.to_html5_video())
# Out:
# (500, 20)
# (500, 1)
# (500, 20)
# <video width="640" height="480" controls autoplay>
#   <source type="video/mp4" src="...

# %%
## Added Code to check visually the difference in signals from the model and the actual sample

# %matplotlib inline
import matplotlib.pyplot as plt
    
entry_id = 0
outside = 0

x_new = []
y_new = []
while (entry_id < x_test.shape[0]):
    angle = x_test[entry_id:entry_id+1][0][0]
    if (angle > 3 or angle < -3):
        outside += 1
    else:
        x_new.append(x_test[entry_id])
        y_new.append(y_keras[entry_id])
    entry_id += 1
entry_id -= 1
x_new = np.array(x_new)
y_new = np.array(y_new)
print(outside)
x = np.arange(1, N_PARAMS+1, 1)
y = y_test[entry_id:entry_id+1,:N_PARAMS][0]
y_pr = y_keras[entry_id:entry_id+1,:N_PARAMS][0]

plt.plot(x, y, marker='o', linestyle='--', color='r', label='actual') 
plt.plot(x, y_pr, marker='o', linestyle='--', color='g', label='predicted') 
plt.legend(loc="upper right")
plt.xticks(x, x)
angle = x_test[entry_id:entry_id+1][0][0]
plt.title('Gate parameter (angle) {}'.format(angle))
plt.ylabel('Amplitude')
plt.xlabel('Pulse parameters')
plt.show()
# Out:
# 23753

# %%
import random
hash_id = random.getrandbits(32)

if FIDELITY_ENABLED:
    xgate_fidelity_keras = get_xgate_fidelity(x_test, y_keras,
    #xgate_fidelity_keras = get_xgate_fidelity(x_new, y_new,
                                              limit=x_test.shape[0],
                                              #limit=1000,
                                              config_template=CONFIG_TEMPLATE_JSON,
                                              pulse_data_path='/tmp/xgate_{:x}.csv'.format(hash_id),
                                              output_objf_path='/tmp/xgate_fidelity_{:x}.csv'.format(hash_id))
else:
    xgate_fidelity_keras = None
# Out:
# WARNING: Limiting fidelity computation to 524288 entries out of 524288
# 0

# %% [markdown]
# Save metrics values to file for future reference.

# %%
metrics_filename = PREFIX + '/metrics.csv'

# You can disable the writing if necessary.
write_metrics_csv = True

# %%
from utils.metrics import write_metrics
if write_metrics_csv:
    write_metrics(metrics_filename, 'Keras', model_id, mse, msle, mape, xgate_fidelity_keras)

# %%
from utils.metrics import print_metrics
print_metrics(metrics_filename)
# Out:
#                    Date Framework  \
# 0   26/03/2023 15:27:33     Keras
# 1   26/03/2023 16:27:23     Keras
# 2   26/03/2023 16:47:38     Keras
# 3   26/03/2023 17:00:03     Keras
# 4   26/03/2023 17:15:21     Keras
# 5   26/03/2023 17:33:17     Keras
# 6   26/03/2023 18:30:53     Keras
# 7   26/03/2023 18:44:26     Keras
# 8   26/03/2023 19:31:18     Keras
# 9   26/03/2023 19:52:43     Keras
# 10  26/03/2023 20:18:34     Keras
# 11  26/03/2023 20:26:32     Keras
# 12  26/03/2023 22:43:17     Keras
# 13  26/03/2023 23:42:32     Keras
# 14  26/03/2023 23:58:38     Keras
# 15  27/03/2023 00:18:49     Keras
# 16  27/03/2023 00:53:38     Keras
# 17  27/03/2023 01:32:20     Keras
# 18  27/03/2023 02:09:13     Keras
# 19  27/03/2023 02:57:02     Keras
# 20  01/04/2023 01:44:16     Keras
# 21  01/04/2023 01:54:20     Keras
# 22  02/04/2023 03:36:08     Keras
# 23  02/04/2023 04:46:01     Keras
# 24  02/04/2023 08:14:45     Keras
# 25  03/04/2023 19:36:49     Keras
# 26  03/04/2023 19:42:43     Keras
# 27  06/04/2023 00:09:16     Keras
# 28  06/04/2023 23:43:09     Keras
# 29  07/04/2023 00:25:13     Keras
# 30  08/04/2023 15:31:59     Keras
# 31  08/04/2023 15:49:36     Keras
# 32  08/04/2023 16:23:39     Keras
#
#                                                ID            MSE  MSLE  MAPE  \
# 0   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000000107501   NaN   NaN
# 1   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000000144451   NaN   NaN
# 2   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000000159653   NaN   NaN
# 3   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000002238557   NaN   NaN
# 4   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000022899336   NaN   NaN
# 5   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000003620726   NaN   NaN
# 6   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000000458110   NaN   NaN
# 7   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000001081720   NaN   NaN
# 8   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000000128790   NaN   NaN
# 9   largeMLP_1x128x128x128x128x128x128x128x128x20 0.000001256145   NaN   NaN
# 10  largeMLP_1x128x128x128x128x128x128x128x128x20 0.000001256145   NaN   NaN
# 11  largeMLP_1x128x128x128x128x128x128x128x128x20 0.000001256145   NaN   NaN
# 12             smallMLP_1x16x16x16x16x16x16x16x20 0.000000082061   NaN   NaN
# 13                   smallMLP_1x16x16x16x16x16x20 0.000000106796   NaN   NaN
# 14                         smallMLP_1x16x16x16x20 0.000000944260   NaN   NaN
# 15                      smallMLP_1x16x16x16x16x20 0.000000836411   NaN   NaN
# 16                   smallMLP_1x16x16x16x16x16x20 0.000000255845   NaN   NaN
# 17                   smallMLP_1x16x16x16x16x16x20 0.000000268845   NaN   NaN
# 18                smallMLP_1x16x16x16x16x16x16x20 0.000000087958   NaN   NaN
# 19             smallMLP_1x16x16x16x16x16x16x16x20 0.000000086295   NaN   NaN
# 20                smallMLP_1x16x16x16x16x16x16x20 0.000000089138   NaN   NaN
# 21                smallMLP_1x16x16x16x16x16x16x20 0.000000089138   NaN   NaN
# 22                     smallMLP_1x8x16x8x8x8x8x20 0.000000120993   NaN   NaN
# 23                        smallMLP_1x16x8x16x8x20 0.000000155496   NaN   NaN
# 24                smallMLP_1x16x16x16x16x16x16x20 0.000000069004   NaN   NaN
# 25               lLargeMLP_1x16x16x16x16x16x16x20 0.000000069004   NaN   NaN
# 26                smallMLP_1x16x16x16x16x16x16x20 0.000000069004   NaN   NaN
# 27                smallMLP_1x16x16x16x16x16x16x20 0.000000078962   NaN   NaN
# 28                smallMLP_1x16x16x16x16x16x16x20 0.000000133412   NaN   NaN
# 29                  smallMLP_1x16x16x8x8x8x8x8x20 0.000000177439   NaN   NaN
# 30                smallMLP_1x16x16x16x16x16x16x20 0.000000104752   NaN   NaN
# 31                smallMLP_1x16x16x16x16x16x16x20 0.000000069004   NaN   NaN
# 32                   ktbo_MLP_1x8x8x8x12x16x16x20 0.000000127273   NaN   NaN
#
#          Fidelity
# 0  0.999813338642
# 1  0.999521928451
# 2  0.999262346996
# 3  0.967716975306
# 4  0.500383998067
# 5  0.973792933780
# 6  0.992171543583
# 7  0.999109099766
# 8  0.999283289804
# 9  0.999979858363
# 10 0.999979858363
# 11 0.999979867830
# 12 0.999600649640
# 13 0.999846187709
# 14 0.993041272964
# 15 0.990556123908
# 16 0.996120175435
# 17 0.996231964269
# 18 0.999423406088
# 19 0.999531647842
# 20 0.999461509983
# 21 0.999358020811
# 22 0.998674188345
# 23 0.998269299548
# 24 0.999691051529
# 25 0.999691051529
# 26 0.999691051529
# 27 0.999582050269
# 28 0.998781373819
# 29 0.998657877096
# 30 0.999185960196
# 31 0.999691080062
# 32 0.998951181797
